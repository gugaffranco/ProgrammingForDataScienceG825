# %% [markdown]
# <h1 style = "color : #0EE071; text-align : center;"><em>Where should I live?</em> - Data Exploration Notebook</h1>
# <p style = "font-size : 16px; text-align: center;">This notebook is dedicated only to the exploration of the <code>city_data</code> dataset</p>
# <br>
# <p style = "font-size : 12px; text-align: center;"><b>NOVA IMS</b></p>
# <p style = "font-size : 10px; text-align: center;">Programming for Data Science</p>
# <p style = "font-size : 10px; text-align: center;">Diogo Gonçalves, João Marques, Juan Mendes & Gustavo Franco</p>
# <br>

# %% [markdown]
# <h2  style = "color : #0EE071;"> Imports</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <hr style = "border: 3px solid #0EE071;">
# <h2 style = "color : #0EE071;">Dataset Reading </h2>
# <p style = "font-size : 15px;">Reading of dataset from <code>city_data.csv</code> file</p>
# <p>The dataset is in a <code>.csv</code> file, and uses <code>|</code> as a separator. The first row of the file is also blank, so we read it using <code>skiprows = 1</code>. </p>

# %%
city_data = pd.read_csv("city_data.csv", sep = "|", skiprows = 1)
city_data.head()
# Out:
#                 City  Population Density  Population  Working Age Population   \
# 0    Vienna, Austria               310.0     2983513                2018818.0
# 1  Salzburg, Austria               243.0      375489                 250472.0
# 2  Brussels, Belgium               681.0     3284548                2137425.0
# 3   Antwerp, Belgium               928.0     1139663                 723396.0
# 4      Gent, Belgium               552.0      645813                 417832.0
#
#    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 0                    20.1               10.2         55770.0
# 1                    20.3                3.0         66689.0
# 2                    27.5               10.7         62500.0
# 3                    27.7                6.2         57595.0
# 4                    24.8                NaN         53311.0
#
#    Days of very strong heat stress              Main Spoken Languages  \
# 0                                3  German, English, Turkish, Serbian
# 1                                0                             German
# 2                                3     French, Dutch, Arabic, English
# 3                                3              Dutch, French, Arabic
# 4                                2                      Dutch, French
#
#    Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 0                    2500                 1050                    2061
# 1                    3200                 1100                    2186
# 2                    3350                 1200                    1900
# 3                    2609                  900                    1953
# 4                    2400                  827                    1200
#
#    Average Price Groceries     Last Data Update
# 0                    340.0  2024-06-15 00:00:00
# 1                      NaN  2023-11-03 00:00:00
# 2                      NaN  2023-04-22 00:00:00
# 3                      NaN  2024-08-09 00:00:00
# 4                    120.0  2023-07-17 00:00:00

# %% [markdown]
# <hr style = "border: 3px solid #0EE071;">
# <h2  style = "color : #0EE071;">Dataset Strucure</h2>
# <p style = "font-size : 15px;">Exploration of the structure of <code>city_data</code> dataset</p>

# %%
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             86 non-null     object
#  1   Population Density               85 non-null     float64
#  2   Population                       86 non-null     int64
#  3   Working Age Population           85 non-null     float64
#  4   Youth Dependency Ratio           86 non-null     float64
#  5   Unemployment Rate                85 non-null     float64
#  6   GDP per Capita                   85 non-null     float64
#  7   Days of very strong heat stress  86 non-null     int64
#  8   Main Spoken Languages            85 non-null     object
#  9   Average Monthly Salary           86 non-null     int64
#  10  Avgerage Rent Price              86 non-null     int64
#  11  Average Cost of Living           86 non-null     int64
#  12  Average Price Groceries          6 non-null      float64
#  13  Last Data Update                 86 non-null     object
# dtypes: float64(6), int64(5), object(3)
# memory usage: 9.5+ KB

# %%
city_data.describe()
# Out:
#        Population Density    Population  Working Age Population   \
# count           85.000000  8.600000e+01             8.500000e+01
# mean          1115.141176  1.754370e+06             1.158294e+06
# std           2542.778533  1.843133e+06             1.232534e+06
# min             65.000000  7.389500e+04             4.635900e+04
# 25%            304.000000  5.281185e+05             3.580200e+05
# 50%            548.000000  1.178397e+06             7.337940e+05
# 75%           1020.000000  2.315896e+06             1.534225e+06
# max          20983.000000  1.239654e+07             8.274794e+06
#
#        Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# count               86.000000          85.000000       85.000000
# mean                24.096860           6.667059    51750.269647
# std                  3.266421           4.553632    21495.617843
# min                 19.300000           1.400000    10089.920000
# 25%                 21.425000           3.700000    38664.000000
# 50%                 23.150000           5.300000    49329.000000
# 75%                 25.925000           8.100000    63083.000000
# max                 37.800000          23.000000   146094.000000
#
#        Days of very strong heat stress  Average Monthly Salary  \
# count                        86.000000               86.000000
# mean                          4.348837             2434.488372
# std                          10.038476             1188.602984
# min                           0.000000              750.000000
# 25%                           0.000000             1412.500000
# 50%                           1.000000             2400.000000
# 75%                           3.000000             3200.000000
# max                          59.000000             6636.000000
#
#        Avgerage Rent Price  Average Cost of Living  Average Price Groceries
# count            86.000000               86.000000                 6.000000
# mean           1070.104651             1808.383721               225.833333
# std             498.964576              727.999680                97.890585
# min             100.000000              800.000000               100.000000
# 25%             800.000000             1300.000000               147.500000
# 50%            1050.000000             1665.000000               243.000000
# 75%            1250.000000             2100.000000               295.750000
# max            3190.000000             4862.000000               340.000000

# %% [markdown]
# <h3>Data Structure Overview</h3>
#
# <ul>
# <li>The dataset contains <b>13 columns</b> and <b>85 rows</b>.</li>
# <li>Each row represents a <b>European city</b>.</li>
# <li>The variable <code>City</code> stores both the name of the city and its country.</li>
# <li>The variables <code>Population Density</code>, <code>Working Age Population</code>, <code>Unemployment Rate</code>, <code>GDP per capita</code> and <code>Main Spoken Languages</code> <b>have 1 missing value</b>.</li>
# <li>Only 6 cities have a known <code>Average Price Groceries</code> in this dataset.</li>
# </ul> </p>
# <br>
# <br>

# %% [markdown]
# <hr style = "border: 3px solid #0EE071;">
# <h2 style = "color : #0EE071;">Variable Outline</h2>
# <p style = "font-size : 16px;">Exploration of each variable independently.</p>
# <br>

# %% [markdown]
# <h3><code>City</code></h3>
# <p style = "font-size : 15px;"><b>Name of the city and country. Acts as unique identifier.</b></p>
# <p><b>Data Type:</b> object/string</p>
# <p><b>Missing Values:</b> 0</p>

# %% [markdown]
# <h4>Search for duplicates, if any:</h4>
# <p>This is useful, as this variable acts as a unique identifier (no cities have the same name and are from the same country), it will guide us towards duplicate rows.</p>

# %%
int(city_data['City'].duplicated().sum()) #if we do not use int(...), the result will be presented with np.int(...) as it is a result of .sum()
# Out:
# 2

# %% [markdown]
# <p>By checking the sum of the duplicated rows, we can see that there are two rows that are duplicated. Therefore, we have to see what are the duplicated rows:</p>

# %%
city_data[city_data['City'].duplicated(keep=False)]
# Out:
#                City  Population Density  Population  Working Age Population   \
# 15  Berlin. Germany               304.0     5303922                3481212.0
# 16  Berlin. Germany               304.0     5303922                3481212.0
# 32    Malaga, Spain               571.0      869096                 585608.0
# 33    Malaga, Spain               571.0      869096                 585608.0
#
#     Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 15                    21.3                4.7         46548.0
# 16                    21.3                4.7         46548.0
# 32                    23.5               17.7         27694.0
# 33                    23.5               17.7         27694.0
#
#     Days of very strong heat stress             Main Spoken Languages  \
# 15                                3  German, Turkish, Arabic, English
# 16                                3  German, Turkish, Arabic, English
# 32                                0                  Spanish, English
# 33                                0                  Spanish, English
#
#     Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 15                    3200                 1220                    2200
# 16                    3200                 1220                    2200
# 32                    2200                 1312                    1400
# 33                    2200                 1312                    1400
#
#     Average Price Groceries     Last Data Update
# 15                      NaN  2023-06-29 00:00:00
# 16                      NaN  2023-06-29 00:00:00
# 32                      NaN  2023-11-27 00:00:00
# 33                      NaN  2023-11-27 00:00:00

# %%
city_data.iloc[15,:] == city_data.iloc[16,:]
# Out:
# City                                True
# Population Density                  True
# Population                          True
# Working Age Population              True
# Youth Dependency Ratio              True
# Unemployment Rate                   True
# GDP per Capita                      True
# Days of very strong heat stress     True
# Main Spoken Languages               True
# Average Monthly Salary              True
# Avgerage Rent Price                 True
# Average Cost of Living              True
# Average Price Groceries            False
# Last Data Update                    True
# dtype: bool

# %%
city_data.iloc[32,:] == city_data.iloc[33,:]
# Out:
# City                                True
# Population Density                  True
# Population                          True
# Working Age Population              True
# Youth Dependency Ratio              True
# Unemployment Rate                   True
# GDP per Capita                      True
# Days of very strong heat stress     True
# Main Spoken Languages               True
# Average Monthly Salary              True
# Avgerage Rent Price                 True
# Average Cost of Living              True
# Average Price Groceries            False
# Last Data Update                    True
# dtype: bool

# %% [markdown]
# <p style = "border: 3px solid #0EE071; padding: 10px; border-radius: 6px;">
# Here we can see that <code>Berlin. Germany</code> (in rows indexes 15 and 16) and <code>Malaga, Spain</code> (in rows indexes 32 and 33) are duplicate.
# We can also tell that the two pairs of rows are completly duplicated (on all columns). As the result of their comparison is <code>True</code> for all columns, excluding <code>Average Price Groceries</code> whose values are both null.</p>
# <br>

# %% [markdown]
# <h4>What are the separators between the City name and Country name?</h4>
# <p>Using the .head() attribute we could see the variable <code>City</code> being the City name followed by the Country it is in, with a comma separiting them. In the duplicates, we had an example of a point being used for the separated. Are there any more separators used?</p>

# %%
city_data[~city_data['City'].str.contains(', ', regex=False) & ~city_data['City'].str.contains('. ', regex=False)]
# Out:
#               City  Population Density  Population  Working Age Population   \
# 12  Lemesos;Cyprus               190.0      262238                 173906.0
#
#     Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 12                   23.06               11.2             NaN
#
#     Days of very strong heat stress    Main Spoken Languages  \
# 12                                0  Greek, English, Russian
#
#     Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 12                    2500                 1400                    2300
#
#     Average Price Groceries     Last Data Update
# 12                      NaN  2023-08-14 00:00:00

# %% [markdown]
# <p>We have filtered the ones that don't have any comma or point and found only <code>Lemesos;Cyprus</code> that uses semicolon. Now let's see how many (and which ones) use comma and how many use point:</p>

# %%
city_data[city_data['City'].str.contains(',', regex=False)]
# Out:
#                   City  Population Density  Population  \
# 0      Vienna, Austria               310.0     2983513
# 1    Salzburg, Austria               243.0      375489
# 2    Brussels, Belgium               681.0     3284548
# 3     Antwerp, Belgium               928.0     1139663
# 4        Gent, Belgium               552.0      645813
# ..                 ...                 ...         ...
# 81   Stockholm, Sweden               334.0     2344124
# 82  Gothenburg, Sweden               245.0     1037675
# 83       Malmo, Sweden               368.0      680335
# 84     Ankara, Turkiye              1922.0     4843511
# 85      Adana, Turkiye               552.0     1074543
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 0                 2018818.0                    20.1               10.2
# 1                  250472.0                    20.3                3.0
# 2                 2137425.0                    27.5               10.7
# 3                  723396.0                    27.7                6.2
# 4                  417832.0                    24.8                NaN
# ..                      ...                     ...                ...
# 81                1534225.0                    28.5                6.2
# 82                 672152.0                    28.2                6.3
# 83                 436271.0                    29.4                9.2
# 84                3417691.0                    30.0               14.4
# 85                 718256.0                    37.8               12.2
#
#     GDP per Capita  Days of very strong heat stress  \
# 0          55770.0                                3
# 1          66689.0                                0
# 2          62500.0                                3
# 3          57595.0                                3
# 4          53311.0                                2
# ..             ...                              ...
# 81         70950.0                                0
# 82         49588.0                                0
# 83         44387.0                                0
# 84         38916.0                                3
# 85         19945.0                               59
#
#                 Main Spoken Languages  Average Monthly Salary  \
# 0   German, English, Turkish, Serbian                    2500
# 1                              German                    3200
# 2      French, Dutch, Arabic, English                    3350
# 3               Dutch, French, Arabic                    2609
# 4                       Dutch, French                    2400
# ..                                ...                     ...
# 81                   Swedish, English                    2700
# 82                   Swedish, English                    2500
# 83                   Swedish, English                    2400
# 84                            Turkish                     900
# 85                            Turkish                     750
#
#     Avgerage Rent Price  Average Cost of Living  Average Price Groceries  \
# 0                  1050                    2061                    340.0
# 1                  1100                    2186                      NaN
# 2                  1200                    1900                      NaN
# 3                   900                    1953                      NaN
# 4                   827                    1200                    120.0
# ..                  ...                     ...                      ...
# 81                 1400                    2300                      NaN
# 82                 1200                    2100                      NaN
# 83                 1100                    2000                      NaN
# 84                  450                     900                    309.0
# 85                  350                     800                      NaN
#
#        Last Data Update
# 0   2024-06-15 00:00:00
# 1   2023-11-03 00:00:00
# 2   2023-04-22 00:00:00
# 3   2024-08-09 00:00:00
# 4   2023-07-17 00:00:00
# ..                  ...
# 81  2024-09-11 00:00:00
# 82  2023-03-10 00:00:00
# 83  2024-07-07 00:00:00
# 84  2023-06-08 00:00:00
# 85  2024-05-02 00:00:00
#
# [83 rows x 14 columns]

# %%
city_data[city_data['City'].str.contains('.', regex=False)]
# Out:
#                City  Population Density  Population  Working Age Population   \
# 15  Berlin. Germany               304.0     5303922                3481212.0
# 16  Berlin. Germany               304.0     5303922                3481212.0
#
#     Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 15                    21.3                4.7         46548.0
# 16                    21.3                4.7         46548.0
#
#     Days of very strong heat stress             Main Spoken Languages  \
# 15                                3  German, Turkish, Arabic, English
# 16                                3  German, Turkish, Arabic, English
#
#     Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 15                    3200                 1220                    2200
# 16                    3200                 1220                    2200
#
#     Average Price Groceries     Last Data Update
# 15                      NaN  2023-06-29 00:00:00
# 16                      NaN  2023-06-29 00:00:00

# %% [markdown]
# <p style = "border: 3px solid #0EE071; padding: 10px; border-radius: 6px;">
# Concluding that <code>Berlin. Germany</code> is the only entry using a point, <code>Lemesos;Cyprus</code> is the only using a semicolon and all the other 83 rows (82 cities, as Malaga is duplicate) use a comma.</p>
# <br>

# %% [markdown]
# <h3><code>Population Density</code></h3>
# <p style = "font-size : 15px;"><b>Number of inhabitants per km2.</b></p>
# <p><b>Data Type:</b> float64</p>
# <p><b>Missing Values:</b> 1</p>

# %% [markdown]
# <h4>Search for the missing value:</h4>

# %%
city_data[city_data['Population Density'].isna()]
# Out:
#                City  Population Density  Population  Working Age Population   \
# 30  Valencia, Spain                 NaN     1748142                1162828.0
#
#     Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 30                    22.6               13.7         33570.0
#
#     Days of very strong heat stress Main Spoken Languages  \
# 30                                5     Spanish;Valencian
#
#     Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 30                    2400                 1190                    1300
#
#     Average Price Groceries     Last Data Update
# 30                      NaN  2023-06-04 00:00:00

# %% [markdown]
# <p style = "border: 3px solid #0EE071; padding: 10px; border-radius: 6px;">
# Concluding that <code>Valencia, Spain</code> is the city that doesn't have a known value for <code>Population Density</code>.</p>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.hist(city_data["Population Density"].dropna(), bins = 100) 
ax2.boxplot(city_data["Population Density"].dropna()) 

ax1.set_title("Variable Distribution") 
ax2.set_title("Outliers and Quantiles") 

plt.show()

# %%
city_data['Population Density'].describe()
# Out:
# count       85.000000
# mean      1115.141176
# std       2542.778533
# min         65.000000
# 25%        304.000000
# 50%        548.000000
# 75%       1020.000000
# max      20983.000000
# Name: Population Density, dtype: float64

# %% [markdown]
# <h3><code>Population</code></h3>
# <p style = "font-size : 15px;"><b>Number of inhabitants per km2.</b></p>
# <p><b>Data Type:</b> int64</p>
# <p><b>Missing Values:</b> 0</p>

# %%
# Create figure and axes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Histogram — raw population distribution
ax1.hist(city_data["Population"], bins=100)
ax1.set_title("Distribution of Population")
ax1.set_xlabel("Population (inhabitants)")
ax1.set_ylabel("Frequency")

# Boxplot — to highlight outliers
ax2.boxplot(city_data["Population"])
ax2.set_title("Population — Outliers and Quartiles")
ax2.set_ylabel("Population (inhabitants)")

# Global title and layout
fig.suptitle("Population Variable  European Cities")
plt.tight_layout()
plt.show()

# %%
city_data['Population'].describe()
# Out:
# count    8.600000e+01
# mean     1.754370e+06
# std      1.843133e+06
# min      7.389500e+04
# 25%      5.281185e+05
# 50%      1.178397e+06
# 75%      2.315896e+06
# max      1.239654e+07
# Name: Population, dtype: float64
